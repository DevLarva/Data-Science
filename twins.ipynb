# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
cd /content/drive/MyDrive/Github/Data-Science

# %%
# !git config --global user.email 'bdh3620@naver.com'
# !git config --global user.name 'bdh3620'

# %%
cd/content/drive/MyDrive/Github

# %%
# !git clone https://bdh3620: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@github.com/bdh3620/Data-Science.git

# %%
cd Data-Science/

# %%
# !git config --global user.email 'bdh3620@naver.com'
# !git config --global user.name 'bdh3620'

# %%
import pandas as pd
import os
from skimage.transform import resize
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt
Categories=['jorgy','luy','brother2']
flat_data_arr=[] #input array
target_arr=[] #output array
datadir='/content/drive/MyDrive/brother' 
#path which contains all the categories of images
for i in Categories:
    
    print(f'loading... category : {i}')
    path=os.path.join(datadir,i)
    for img in os.listdir(path):
        img_array=imread(os.path.join(path,img))
        img_resized=resize(img_array,(150,150,3))
        flat_data_arr.append(img_resized.flatten())
        target_arr.append(Categories.index(i))
    print(f'loaded category:{i} successfully')
flat_data=np.array(flat_data_arr)
target=np.array(target_arr)
df=pd.DataFrame(flat_data) #dataframe
df['Target']=target
x=df.iloc[:,:-1] #input data 
y=df.iloc[:,-1] #output data
from google.colab import drive
drive.mount('/content/drive/')

# %% [markdown]
# # 새 섹션

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.1,1,10,100],'gamma':[0.0001,0.001,0.1,1],'kernel':['rbf','poly']}
svc=svm.SVC(probability=True)
model=GridSearchCV(svc,param_grid)
